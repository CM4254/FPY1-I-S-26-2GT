# %% [markdown]
# <a href="https://colab.research.google.com/github/CM4254/FPY1-I-S-26-2GT/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("VAMOS CALCULAR SEU IMC?")
ALTURA = int(input("Sua Altura "))
PESO = int(input("Seu Peso "))
imc = round((PESO/((ALTURA*2)/100)),2)
if (imc  < 18.5):
  print(f"Seu imc é {imc} - Abaixo do peso")
elif (imc >= 18.5 and imc < 25):
   print(f"Seu imc é {imc} -  Peso normal")
elif ( imc >= 25 and imc <30):
   print(f"Seu imc é {imc} - Sobrepeso")
elif ( imc >= 30 and imc <40):
   print(f"Seu imc é {imc} - Obesidade")
else:
     print(f"Seu imc é {imc} - Obesidade Grave")

# %%
from datetime import date
ANO_ATUAL  = int(date.today().year)
print("Digite o ano do seu nascimento: ")
NASC = int(input())
IDADE =  (ANO_ATUAL - NASC)
print(f"sua idade é {IDADE} anos")

# %%
from datetime import date
ANO_ATUAL  = int(date.today().year)
MES_ATUAL = int(date.today().month)
DIA_ATUAL = int(date.today().day)

print("Digite o ano do seu nascimento: ")
ano = int(input())
print("Digite o mês do seu nascimento: ")
mes = int(input())
print("Digite o dia do seu nascimento: ")
dia = int(input())


IDADEDIF =  (ANO_ATUAL - ano) -1
IDADE =  (ANO_ATUAL - ano)

if (MES_ATUAL < mes) :
    print(f"sua idade é {IDADEDIF} anos")
elif (MES_ATUAL == mes) and (DIA_ATUAL < dia):
    print(f"sua idade é {IDADEDIF} anos")
else:
    print(f"sua idade é {IDADE} anos")

# %%
print("Calculadora de diferença")
print("Formula Diferença: (A * B - C * D)")
print("Digite 4 valores: ")
a = int(input("Valor A: "))
b = int(input("Valor B: "))
c = int(input("Valor C: "))
d = int(input("Valor D: "))
dif = (a*b)-(c*d)
print(f"a diferença é {dif}")

# %%
palavra = input("Digite sua palavra ")
vogais = {"A", "E", "I", "O", "U", "a", "e", "i", "o", "u"}
consoantes = {
    "B","C","D","F","G","H","J","K","L","M","N","P","Q","R","S","T","V","W","X","Y","Z",
    "b","c","d","f","g","h","j","k","l","m","n","p","q","r","s","t","v","w","x","y","z"
}

vogaisc = 0
consoantesc = 0

for caract in palavra:

    if caract in vogais:

      vogaisc +=1

for caract in palavra:

    if caract in consoantes:

      consoantesc +=1

print(f"A quantidade de vogais é {vogaisc}")
print(f"A quantidade de consoantes é {consoantesc}")

# %%
import random
n = random.randrange(1, 11)



print("Jogo de adivinhação")
print("tente adivinhar um numero entre 1 e 10")




while True:
  try:
    getsenha = int((input("Digite o palpite:")))

    if getsenha == n:
      print((f"Senha correta {n}"))
      break
    elif getsenha < n:
      print("seu palpite está baixo")
    else:
      print("Seu palpite está alto")

  except erro:
    print("erro")

# %%
def solicitarnumero ():
    return int(input("valor inteiro "))

def geralista (num):
    resultado = []
    for i in range(num):
        resultado.append(num)
    return resultado

nvalor = solicitarnumero()
gerarlista = geralista(nvalor)
print(f"A lista gerada é: {gerarlista}")

# %%
def solicitarnumero():
    return int(input("valor inteiro: "))

def validador(valor):
    if valor <= 0:
        print(f"O valor digitado {valor} é negativo")
    else:
        print(f"O valor digitado {valor} é positivo")

nvalor = solicitarnumero()
validador(nvalor)
